# %%
# Importing pandas
import pandas as pd

# adjust display settings to show all rows
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.expand_frame_repr', False)  # Prevents column wrapping

# Reads the CSV file into a DataFrame
# df is the data frame
# use r
df = pd.read_csv(r'C:\Users\rodri\Downloads\sales_data.csv')

# Prints the first 5 rows of the DataFrame
print(df.head())
# Out:
#    order_id customer_id  order_date     product     category  quantity  unit_price region
# 0  ORD_0001    CUST_048  2023-01-26  Headphones  Electronics         4      380.79   East
# 1  ORD_0002    CUST_048  2023-05-23       Jeans     Clothing         9      951.21  North
# 2  ORD_0003    CUST_028  2024-08-27  Headphones  Electronics         1      734.67  North
# 3  ORD_0004    CUST_015  2023-08-12  Headphones  Electronics         9      602.67  North
# 4  ORD_0005    CUST_045  2024-10-27       Jeans     Clothing         4      164.46   West

# %%
# see all the data frame
print(df)
# Out:
#      order_id customer_id order_date         product     category  quantity  unit_price region
# 0    ORD_0001    CUST_048 2023-01-26      Headphones  Electronics         4      380.79   East
# 1    ORD_0002    CUST_048 2023-05-23           Jeans     Clothing         9      951.21  North
# 2    ORD_0003    CUST_028 2024-08-27      Headphones  Electronics         1      734.67  North
# 3    ORD_0004    CUST_015 2023-08-12      Headphones  Electronics         9      602.67  North
# 4    ORD_0005    CUST_045 2024-10-27           Jeans     Clothing         4      164.46   West
# 5    ORD_0006    CUST_018 2024-08-26          Tablet  Electronics         3      164.43  North
# 6    ORD_0007    CUST_018 2023-12-15        Sneakers     Clothing         4       67.50  South
# 7    ORD_0008    CUST_006 2023-04-15  Vacuum Cleaner         Home         2      867.51   West
# 8    ORD_0009    CUST_039 2023-12-19  Vacuum Cleaner         Home         1      605.10   East
# ...

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   order_id     200 non-null    object
#  1   customer_id  200 non-null    object
#  2   order_date   200 non-null    object
#  3   product      200 non-null    object
#  4   category     200 non-null    object
#  5   quantity     200 non-null    int64
#  6   unit_price   200 non-null    float64
#  7   region       200 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 12.6+ KB
# None

# %%
# covnert from object to date
df['order_date'] = pd.to_datetime(df['order_date'], format='%b %d, %Y')
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   order_id     200 non-null    object
#  1   customer_id  200 non-null    object
#  2   order_date   200 non-null    datetime64[ns]
#  3   product      200 non-null    object
#  4   category     200 non-null    object
#  5   quantity     200 non-null    int64
#  6   unit_price   200 non-null    float64
#  7   region       200 non-null    object
# dtypes: datetime64[ns](1), float64(1), int64(1), object(5)
# memory usage: 12.6+ KB
# None

# %%
print(df)
# Out:
#      order_id customer_id order_date         product     category  quantity  unit_price region
# 0    ORD_0001    CUST_048 2023-01-26      Headphones  Electronics         4      380.79   East
# 1    ORD_0002    CUST_048 2023-05-23           Jeans     Clothing         9      951.21  North
# 2    ORD_0003    CUST_028 2024-08-27      Headphones  Electronics         1      734.67  North
# 3    ORD_0004    CUST_015 2023-08-12      Headphones  Electronics         9      602.67  North
# 4    ORD_0005    CUST_045 2024-10-27           Jeans     Clothing         4      164.46   West
# 5    ORD_0006    CUST_018 2024-08-26          Tablet  Electronics         3      164.43  North
# 6    ORD_0007    CUST_018 2023-12-15        Sneakers     Clothing         4       67.50  South
# 7    ORD_0008    CUST_006 2023-04-15  Vacuum Cleaner         Home         2      867.51   West
# 8    ORD_0009    CUST_039 2023-12-19  Vacuum Cleaner         Home         1      605.10   East
# ...

# %%
# Checking if the Column contains any NaN/Nulls
df.isna().any()
# Out:
# order_id       False
# customer_id    False
# order_date     False
# product        False
# category       False
# quantity       False
# unit_price     False
# region         False
# dtype: bool

# %%
# export to csv
df.to_csv(r'C:\Users\rodri\Downloads\exported_sales_data.csv', index=False)
