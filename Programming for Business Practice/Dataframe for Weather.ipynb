# %% [markdown]
# # GBA 6070 - Programming Foundation for Business Analytics
# # Dr. Mohammad Salehan
# # Assignment 9 - Dataframe I
# Enter your name below.

# %% [markdown]
# In this assignment you will work with a weather dataset. Let's start with loading the dataset.

# %%
import pandas as pd
df = pd.read_csv('weather.csv')

# %% [markdown]
# 1. Examine the shape of the dataframe.

# %%
df.shape
# Out:
# (4187, 13)

# %% [markdown]
# 2. Check the top 5 rows to see what it looks like.

# %%
df.head(5)
# Out:
#    Unnamed: 0      Station  Year  Month  Day  Hour  Temperature  Dew Point  \
# 0           0  2003\010000  2003      1    9     6       -119.0        NaN
# 1           1  2003\010000  2003      1   20    18       -174.0     -239.0
# 2           2  2003\010000  2003      1   23     6       -101.0        NaN
# 3           3  2003\010000  2003      4   11    12         18.0        9.0
# 4           4  2003\010000  2003      6   25     8         52.0       45.0
#
#    Pressure  Wind Direction  Wind Speed  Sky Condition  Precipitation 6H
# 0       NaN             200          10            2.0               0.0
# 1   10015.0             260          70            8.0               NaN
# 2       NaN             340         130            9.0               NaN
# 3       NaN             200          20            7.0               NaN
# 4       NaN             130          10            8.0               NaN

# %% [markdown]
# 3. Exclude the first column (Unnamed) then display the top row.

# %%
df = df.iloc[:, 1:]
df.head(1)
# Out:
#        Station  Year  Month  Day  Hour  Temperature  Dew Point  Pressure  \
# 0  2003\010000  2003      1    9     6       -119.0        NaN       NaN
#
#    Wind Direction  Wind Speed  Sky Condition  Precipitation 6H
# 0             200          10            2.0               0.0

# %% [markdown]
# 4. Display Year, Month, Day, Hour, Dew Point, and Wind Speed for the records at row indexes 1000 to 1005 .

# %%
df.loc[1000:1005, ['Year', 'Month', 'Day', 'Hour', 'Dew Point', 'Wind Speed']]
# Out:
#       Year  Month  Day  Hour  Dew Point  Wind Speed
# 1000  2003      2   11    23       -2.0           0
# 1001  2003      2   12     0       -4.0          10
# 1002  2003      2   12     1       -2.0          10
# 1003  2003      2   12     2       -3.0           0
# 1004  2003      2   12     3       -3.0          20
# 1005  2003      2   12     4        5.0          50

# %% [markdown]
# 5. Display all the records where Pressure is larger than 10,000 and Wind Speeds is smaller than 1.

# %%
df[(df['Pressure']>10_000) & (df['Wind Speed']<1)]
# Out:
#           Station  Year  Month  Day  Hour  Temperature  Dew Point  Pressure  \
# 1434  2003\010010  2003      3    4     1         16.0        9.0   10073.0
# 1444  2003\010010  2003      3    4    11          4.0       -4.0   10107.0
# 1717  2003\010010  2003      3   15    22          1.0       -6.0   10212.0
# 1904  2003\010010  2003      3   24    11         15.0        3.0   10018.0
# 2362  2003\010010  2003      4   12    19         12.0       -1.0   10082.0
# 2370  2003\010010  2003      4   13     3          5.0       -5.0   10109.0
# 2601  2003\010010  2003      4   22    22        -16.0      -53.0   10388.0
# 2607  2003\010010  2003      4   23     4         -9.0      -51.0   10377.0
# 2624  2003\010010  2003      4   23    21          5.0      -19.0   10344.0
# 2627  2003\010010  2003      4   24     0          0.0      -27.0   10336.0
# 2628  2003\010010  2003      4   24     1         -1.0      -30.0   10334.0
# ...

# %% [markdown]
# 6. Display the number of missing values in each column.

# %%
df.isnull().sum()
# Out:
# Station                0
# Year                   0
# Month                  0
# Day                    0
# Hour                   0
# Temperature            8
# Dew Point             15
# Pressure              33
# Wind Direction         0
# Wind Speed             0
# Sky Condition       3121
# Precipitation 6H    3904
# dtype: int64

# %% [markdown]
# 7. Display the records where Temprature is null.

# %%
df[df['Temperature'].isnull()]
# Out:
#           Station  Year  Month  Day  Hour  Temperature  Dew Point  Pressure  \
# 8     2003\010000  2003      9    8    18          NaN        NaN   10156.0
# 11    2003\010000  2003     11   23     6          NaN        NaN    9924.0
# 368   2003\010010  2003      1   16     2          NaN        NaN       NaN
# 415   2003\010010  2003      1   18     1          NaN        NaN       NaN
# 1132  2003\010010  2003      2   17    20          NaN        NaN       NaN
# 1443  2003\010010  2003      3    4    10          NaN        NaN       NaN
# 1989  2003\010010  2003      3   28     0          NaN        NaN       NaN
# 3954  2003\010010  2003      6   20    14          NaN        NaN       NaN
#
#       Wind Direction  Wind Speed  Sky Condition  Precipitation 6H
# 8                230          30            4.0               NaN
# 11               110          10            3.0               NaN
# 368              350         130            NaN               NaN
# ...

# %% [markdown]
# 5. Modify ``df`` to replace all the missing values in Temperature column with column mean. Then examine the number of missing values in each column to make sure that the missing values in other columns are not replaced by mean Temperature.

# %%
df = df.fillna(value={'Temperature':df['Temperature'].mean()})
df.isna().sum()
# Out:
# Station                0
# Year                   0
# Month                  0
# Day                    0
# Hour                   0
# Temperature            0
# Dew Point             15
# Pressure              33
# Wind Direction         0
# Wind Speed             0
# Sky Condition       3121
# Precipitation 6H    3904
# dtype: int64

# %% [markdown]
# 6. Modify ``df`` to replace all missing values in Dew Point and Pressure columns with column median. Then examine the number of missing values in each column to make sure the missing values in other columns are not replaced. At this point, there should be missing values left only in the last 2 columns.

# %%
df = df.fillna(value={'Dew Point':df['Dew Point'].median()})
df = df.fillna(value={'Pressure':df['Pressure'].median()})
df.isna().sum()
# Out:
# Station                0
# Year                   0
# Month                  0
# Day                    0
# Hour                   0
# Temperature            0
# Dew Point              0
# Pressure               0
# Wind Direction         0
# Wind Speed             0
# Sky Condition       3121
# Precipitation 6H    3904
# dtype: int64

# %% [markdown]
# 7. Modify ``df`` to replace the remaining missing values with -9999. The examine the number of missing values in each column to make sure there are no more missing values left.

# %%
df.fillna(value=-9999, inplace=True)
df.isna().sum()
# Out:
# Station             0
# Year                0
# Month               0
# Day                 0
# Hour                0
# Temperature         0
# Dew Point           0
# Pressure            0
# Wind Direction      0
# Wind Speed          0
# Sky Condition       0
# Precipitation 6H    0
# dtype: int64

# %% [markdown]
# 8. Check out the top 10 rows of ``df`` to make sure it looks good.

# %%
df.head(10)
# Out:
#        Station  Year  Month  Day  Hour  Temperature  Dew Point  Pressure  \
# 0  2003\010000  2003      1    9     6  -119.000000      -27.0   10124.0
# 1  2003\010000  2003      1   20    18  -174.000000     -239.0   10015.0
# 2  2003\010000  2003      1   23     6  -101.000000      -27.0   10124.0
# 3  2003\010000  2003      4   11    12    18.000000        9.0   10124.0
# 4  2003\010000  2003      6   25     8    52.000000       45.0   10124.0
# 5  2003\010000  2003      7   26    18   132.000000      -27.0   10124.0
# 6  2003\010000  2003      8   10     6    77.000000       71.0   10032.0
# 7  2003\010000  2003      8   27     6   106.000000       67.0   10098.0
# 8  2003\010000  2003      9    8    18     4.570711      -27.0   10156.0
# 9  2003\010000  2003     10   14    12    62.000000       30.0   10368.0
#
#    Wind Direction  Wind Speed  Sky Condition  Precipitation 6H
# 0             200          10            2.0               0.0
# ...

# %% [markdown]
# ## Extra credit question
# The Station columns contains year/station#. Update the column by dropping year. Check out Vectorized String Operations in the book for more information.

# %%
df['Station'] = df['Station'].str.split('\\').str.get(1)
df.head()
# Out:
#   Station  Year  Month  Day  Hour  Temperature  Dew Point  Pressure  \
# 0  010000  2003      1    9     6       -119.0      -27.0   10124.0
# 1  010000  2003      1   20    18       -174.0     -239.0   10015.0
# 2  010000  2003      1   23     6       -101.0      -27.0   10124.0
# 3  010000  2003      4   11    12         18.0        9.0   10124.0
# 4  010000  2003      6   25     8         52.0       45.0   10124.0
#
#    Wind Direction  Wind Speed  Sky Condition  Precipitation 6H
# 0             200          10            2.0               0.0
# 1             260          70            8.0           -9999.0
# 2             340         130            9.0           -9999.0
# 3             200          20            7.0           -9999.0
# 4             130          10            8.0           -9999.0
